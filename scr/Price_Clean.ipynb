# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
import statsmodels.api as sm
from datetime import timedelta, datetime

# %%
import_directory = 'C:\\Users\\emmah\\Google Drive\\Job Applications\\TechnicalAssessment\\Shift\\data'

df_import =pd.read_csv(import_directory + '\\sample.csv')
# Out:
# C:\Users\emmah\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_import.columns
# Out:
# Index(['index_pandas', 'vin', 'days_on_market', 'listing_date_begin',
#        'listing_date_end', 'year', 'make', 'model', 'trim', 'body_style',
#        'transmission', 'mileage', 'accident_count', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'msrp', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'list_price', 'shift_buyer_region'],
#       dtype='object')

# %%
# Drop invalid row that are missing vin or list_price
# Drop variables that are not vehicle attributes
# Drop variables that cannot be used in price predication at the time of listing
drop_cols = ['index_pandas', 
             'days_on_market', 
             'listing_date_end', 'shift_buyer_region']
df_valid = df_import.dropna(subset=['vin', 'list_price']).drop(columns = drop_cols).drop_duplicates().astype({'year': 'str'})
print("Columns: n/{}".format(df_valid.columns))
print("Row count: {}".format(len(df_valid)))
df_valid.sort_values(["vin", "listing_date_begin"])
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'year', 'make', 'model', 'trim',
#        'body_style', 'transmission', 'mileage', 'accident_count',
#        'fuel_economy_city', 'fuel_economy_highway', 'exterior_color', 'msrp',
#        'is_cpo', 'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'list_price'],
#       dtype='object')
# Row count: 395450
#                       vin listing_date_begin  year    make   model  \
# 57683   0HGCV3F93LA014514         2021-02-23  2020   Honda  Accord
# 8404    19XFC1F30LE000679         2021-03-28  2020   Honda   Civic
# 4298    19XFC1F30LE001184         2021-01-11  2020   Honda   Civic
# 4299    19XFC1F30LE001184         2021-01-11  2020   Honda   Civic
# 6629    19XFC1F30LE001699         2021-04-17  2020   Honda   Civic
# ...                   ...                ...   ...     ...     ...
# 675901  WZ1DB4C0XLW032522         2020-09-05  2020  Toyota   Supra
# 666929  WZ1DB4C0XLW032570         2021-04-09  2020  Toyota   Supra
# 666930  WZ1DB4C0XLW032570         2021-04-09  2020  Toyota   Supra
# 565595  WZ1DB4C0XLW032858         2020-08-26  2020  Toyota   Supra
# 652564  WZ1DB4C0XLW032956         2020-11-29  2020  Toyota   Supra
#
#                    trim body_style                        transmission  \
# 57683               NaN      Sedan  Continuously Variable Transmission
# 8404       EX Sedan FWD      Sedan  Continuously Variable Transmission
# 4298       EX Sedan FWD      Sedan  Continuously Variable Transmission
# 4299       EX Sedan FWD      Sedan  Continuously Variable Transmission
# 6629       EX Sedan FWD      Sedan  Continuously Variable Transmission
# ...                 ...        ...                                 ...
# 675901  3.0 Premium RWD      Coupe                           Automatic
# 666929          3.0 RWD      Coupe                           Automatic
# 666930          3.0 RWD      Coupe                           Automatic
# 565595          3.0 RWD      Coupe                   8-Speed Automatic
# 652564  3.0 Premium RWD      Coupe                   8-Speed Automatic
#
#         mileage  accident_count  ...        exterior_color     msrp is_cpo  \
# 57683    7318.0             NaN  ...                  Blue      NaN    NaN
# 8404    24772.0             0.0  ...     Molten Lava Pearl      NaN   True
# 4298    21846.0             0.0  ...  Platinum White Pearl      NaN   True
# 4299    21846.0             0.0  ...  Platinum White Pearl      NaN   True
# 6629    26203.0             0.0  ...                Silver      NaN    NaN
# ...         ...             ...  ...                   ...      ...    ...
# 675901   2880.0             0.0  ...   RENAISSANCE RED 2.0  58478.0    NaN
# 666929   8917.0             0.0  ...                   Red  53555.0    NaN
# 666930   8917.0             0.0  ...                   Red  54555.0    NaN
# 565595   4689.0             0.0  ...   Renaissance Red 2.0      NaN    NaN
# 652564   3200.0             0.0  ...                   Red      NaN    NaN
#
#                      seller_city seller_state seller_type  \
# 57683              Arlington, TX           TX      DEALER
# 8404    North Richland Hills, TX           TX      DEALER
# 4298             Albuquerque, NM           NM      DEALER
# 4299             Albuquerque, NM           NM      DEALER
# 6629            Newport News, VA           VA      DEALER
# ...                          ...          ...         ...
# 675901        Corpus Christi, TX           TX      DEALER
# 666929             Montclair, CA           CA      DEALER
# 666930             Montclair, CA           CA      DEALER
# 565595           Downingtown, PA           PA      DEALER
# 652564               Manheim, PA           PA      DEALER
#
#        seller_is_franchise_dealer seller_is_online_only  \
# 57683                        True                   NaN
# 8404                         True                   NaN
# 4298                         True                   NaN
# 4299                         True                   NaN
# 6629                         True                   NaN
# ...                           ...                   ...
# 675901                       True                   NaN
# 666929                        NaN                   NaN
# 666930                        NaN                   NaN
# 565595                        NaN                   NaN
# 652564                        NaN                   NaN
#
#        seller_ships_nationwide list_price
# 57683                      NaN    26595.0
# 8404                       NaN    21795.0
# 4298                       NaN    20959.0
# 4299                       NaN    21505.0
# 6629                       NaN    21495.0
# ...                        ...        ...
# 675901                     NaN    52466.0
# 666929                     NaN    53555.0
# 666930                     NaN    54555.0
# 565595                     NaN    52990.0
# 652564                     NaN    46987.0
#
# [395450 rows x 22 columns]

# %%
# Calculate data values for imputation

imputation_dict = {}

# Get median values for imputation of numeric variables
numeric_cols = ['mileage', 'accident_count',
       'fuel_economy_city', 'fuel_economy_highway', 'msrp']
for col in numeric_cols:
    median = df_valid[col].median()
    imputation_dict[col] = median
    
# Get imputation values for boolean variables
boolean_cols = ['is_cpo', 'seller_is_franchise_dealer', 'seller_is_online_only', 'seller_ships_nationwide']
boolean_dict = {}
for col in boolean_cols:
    if len(df_valid[df_valid[col]==True])==0:
        imputation_dict[col] = True
    if len(df_valid[df_valid[col]==False])==0:
        imputation_dict[col] = False
    else:
        pass

# Get imputation for categorical variables with majority categies with subcategory counts < 0.1%
categorical_cols = ["trim", "transmission", "exterior_color"]
for col in categorical_cols:
    imputation_dict[col] = 'Other'

print(imputation_dict)
# Out:
# {'mileage': 11473.0, 'accident_count': 0.0, 'fuel_economy_city': 24.0, 'fuel_economy_highway': 31.0, 'msrp': 35495.0, 'is_cpo': False, 'seller_is_franchise_dealer': False, 'seller_is_online_only': True, 'seller_ships_nationwide': False, 'trim': 'Other', 'transmission': 'Other', 'exterior_color': 'Other'}

# %%
# Split into train and test
unique_vins = df_valid['vin'].unique()
print("Number of unique vins: {}".format(len(unique_vins)))

train_vin = np.random.choice(unique_vins, size=int(len(unique_vins)*0.8), replace=False, p=None)
test_vin = unique_vins[~np.in1d(unique_vins, train_vin)]

df_train = df_valid[df_valid['vin'].isin(train_vin)]
df_test = df_valid[df_valid['vin'].isin(test_vin)]
print("test row percentage: {}%".format(round(100*(len(df_test)/len(df_valid)))))

# Check takes long to run
vin_duplicated = []
for i in df_test.index:
    if df_test.loc[i, 'vin'] in list(df_train['vin']):
        vin_duplicated.append(df_test.loc[i, 'vin'])

assert len(vin_duplicated)==0, "Vin number in test and train"
# Out:
# Number of unique vins: 283993
# test row percentage: 20%

# %%
# Group by observations to summarize 

def summarize_vin(group1):
    """Summarizes observations using mode for categorical variables and median for numeric variables"""
    if len(group1) > 1:
        for col in group1.columns:
            if group1[col].count() > 1:
                if np.issubdtype(group1[col], np.number):
                    group1[col] = group1[col].median()
                else:
                    group1[col] = group1[col].value_counts().index[0]
    return group1

def groupby_vehicle(data):
    """Groups by vin and summarizes categorical and numberic variables that are considered static vehicle attributes"""
    static_cols = ['vin',
                   'year', 
                   'make', 
                   'model', 
                   'trim', 
                   'body_style', 
                   'transmission', 
                   'fuel_economy_city', 
                   'fuel_economy_highway', 
                   'exterior_color']
    df_out = data.groupby('vin')[static_cols].apply(summarize_vin).drop_duplicates()
    return df_out

def groupby_listing(data):
    """Groups by vin and listing_date_begin. 
    Summarizes categorical and numberic variables that are considered static vehicle attributes"""
    dynamic_cols = ['vin', 
                'listing_date_begin',
                'mileage', 
                'accident_count',
                'is_cpo',
                'seller_city', 
                'seller_state', 
                'seller_type',
                'seller_is_franchise_dealer', 
                'seller_is_online_only',
                'seller_ships_nationwide', 
                'msrp',
                'list_price']
    df_out = data.groupby(['vin', 'listing_date_begin'])[dynamic_cols].apply(summarize_vin).drop_duplicates()
    return df_out
    
def summarize_obs(data):
    df_vehicle = groupby_vehicle(data)
    df_listing = groupby_listing(data)
    df_out = df_listing.join(df_vehicle.set_index("vin"), on="vin")
    return df_out
    
sample = df_train.head(1000)
df_tidy = summarize_obs(sample)

print("Columns: n/{}".format(df_tidy.columns))
print("Length: {}".format(len(df_tidy)))
print(df_tidy.sort_values(["vin", "listing_date_begin"]).head(100))
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color'],
#       dtype='object')
# Length: 893
#                    vin listing_date_begin  mileage  accident_count is_cpo  \
# 288  19XFC1F30LE004389         2021-04-23   6874.0             0.0   True
# 173  19XFC1F30LE004859         2021-04-01   5601.0             0.0   True
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0    NaN
# 810  19XFC1F30LE202454         2020-07-14   1500.0             0.0   True
# 608  19XFC1F30LE205208         2021-03-27  18500.0             0.0    NaN
# ..                 ...                ...      ...             ...    ...
# 315  19XFC1F38LE203285         2020-08-15   3575.0             0.0    NaN
# 357  19XFC1F38LE204386         2020-12-03   4250.0             0.0   True
# 359  19XFC1F38LE207644         2020-09-24   7056.0             0.0   True
# 28   19XFC1F38LE209314         2020-11-26   5449.0             0.0   True
# 361  19XFC1F39LE000387         2020-12-29   7402.0             0.0   True
#
#             seller_city seller_state seller_type seller_is_franchise_dealer  \
# 288        Santa Fe, NM           NM      DEALER                       True
# 173        Highland, IN           IN      DEALER                       True
# 0             Davie, FL           FL      DEALER                       True
# 810        Portland, OR           OR      DEALER                       True
# 608          Oxnard, CA           CA      DEALER                        NaN
# ..                  ...          ...         ...                        ...
# 315          Tustin, CA           CA      DEALER                       True
# 357          Fresno, CA           CA      DEALER                       True
# 359       Rockville, MD           MD      DEALER                       True
# 28   Cathedral City, CA           CA      DEALER                       True
# 361         Phoenix, AZ           AZ      DEALER                       True
#
#     seller_is_online_only  ... list_price  year   make  model          trim  \
# 288                   NaN  ...    23284.0  2020  Honda  Civic  EX Sedan FWD
# 173                   NaN  ...    21977.0  2020  Honda  Civic  EX Sedan FWD
# 0                     NaN  ...    20833.0  2020  Honda  Civic  EX Sedan FWD
# 810                   NaN  ...    20999.0  2020  Honda  Civic  EX Sedan FWD
# 608                   NaN  ...    21998.0  2020  Honda  Civic  EX Sedan FWD
# ..                    ...  ...        ...   ...    ...    ...           ...
# 315                   NaN  ...    19888.0  2020  Honda  Civic  EX Sedan FWD
# 357                   NaN  ...    22750.0  2020  Honda  Civic  EX Sedan FWD
# 359                   NaN  ...    21991.0  2020  Honda  Civic  EX Sedan FWD
# 28                    NaN  ...    19800.0  2020  Honda  Civic  EX Sedan FWD
# 361                   NaN  ...    20750.0  2020  Honda  Civic  EX Sedan FWD
#
#     body_style                        transmission fuel_economy_city  \
# 288      Sedan  Continuously Variable Transmission              32.0
# 173      Sedan  Continuously Variable Transmission              32.0
# 0        Sedan  Continuously Variable Transmission              32.0
# 810      Sedan  Continuously Variable Transmission              32.0
# 608      Sedan                           Automatic              32.0
# ..         ...                                 ...               ...
# 315      Sedan  Continuously Variable Transmission              32.0
# 357      Sedan  Continuously Variable Transmission              32.0
# 359      Sedan  Continuously Variable Transmission              32.0
# 28       Sedan  Continuously Variable Transmission              32.0
# 361      Sedan  Continuously Variable Transmission              32.0
#
#     fuel_economy_highway         exterior_color
# 288                 42.0  Modern Steel Metallic
# 173                 42.0  Modern Steel Metallic
# 0                   42.0                   Gray
# 810                 42.0  Lunar Silver Metallic
# 608                 42.0                  Black
# ..                   ...                    ...
# 315                 42.0           Lunar Silver
# 357                 42.0   Cosmic Blue Metallic
# 359                 42.0  Modern Steel Metallic
# 28                  42.0                  White
# 361                 42.0   Platinum White Pearl
#
# [100 rows x 22 columns]

# %%
# Impute missing values

def impute_variables(data):
    """
    Use dataset values for imputation of missing variables
    """
    return data.fillna(value=imputation_dict).replace({True:1, False:0})

df_impute = impute_variables(df_tidy)

print("Columns: n/{}".format(df_impute.columns))
print("Length: {}".format(len(df_impute)))
print(df_impute.sort_values(["vin", "listing_date_begin"]).head(100))
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color'],
#       dtype='object')
# Length: 893
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 288  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 173  19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 810  19XFC1F30LE202454         2020-07-14   1500.0             0.0       1
# 608  19XFC1F30LE205208         2021-03-27  18500.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 315  19XFC1F38LE203285         2020-08-15   3575.0             0.0       0
# 357  19XFC1F38LE204386         2020-12-03   4250.0             0.0       1
# 359  19XFC1F38LE207644         2020-09-24   7056.0             0.0       1
# 28   19XFC1F38LE209314         2020-11-26   5449.0             0.0       1
# 361  19XFC1F39LE000387         2020-12-29   7402.0             0.0       1
#
#             seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 288        Santa Fe, NM           NM      DEALER                           1
# 173        Highland, IN           IN      DEALER                           1
# 0             Davie, FL           FL      DEALER                           1
# 810        Portland, OR           OR      DEALER                           1
# 608          Oxnard, CA           CA      DEALER                           0
# ..                  ...          ...         ...                         ...
# 315          Tustin, CA           CA      DEALER                           1
# 357          Fresno, CA           CA      DEALER                           1
# 359       Rockville, MD           MD      DEALER                           1
# 28   Cathedral City, CA           CA      DEALER                           1
# 361         Phoenix, AZ           AZ      DEALER                           1
#
#      seller_is_online_only  ...  list_price  year   make  model          trim  \
# 288                      1  ...     23284.0  2020  Honda  Civic  EX Sedan FWD
# 173                      1  ...     21977.0  2020  Honda  Civic  EX Sedan FWD
# 0                        1  ...     20833.0  2020  Honda  Civic  EX Sedan FWD
# 810                      1  ...     20999.0  2020  Honda  Civic  EX Sedan FWD
# 608                      1  ...     21998.0  2020  Honda  Civic  EX Sedan FWD
# ..                     ...  ...         ...   ...    ...    ...           ...
# 315                      1  ...     19888.0  2020  Honda  Civic  EX Sedan FWD
# 357                      1  ...     22750.0  2020  Honda  Civic  EX Sedan FWD
# 359                      1  ...     21991.0  2020  Honda  Civic  EX Sedan FWD
# 28                       1  ...     19800.0  2020  Honda  Civic  EX Sedan FWD
# 361                      1  ...     20750.0  2020  Honda  Civic  EX Sedan FWD
#
#     body_style                        transmission fuel_economy_city  \
# 288      Sedan  Continuously Variable Transmission              32.0
# 173      Sedan  Continuously Variable Transmission              32.0
# 0        Sedan  Continuously Variable Transmission              32.0
# 810      Sedan  Continuously Variable Transmission              32.0
# 608      Sedan                           Automatic              32.0
# ..         ...                                 ...               ...
# 315      Sedan  Continuously Variable Transmission              32.0
# 357      Sedan  Continuously Variable Transmission              32.0
# 359      Sedan  Continuously Variable Transmission              32.0
# 28       Sedan  Continuously Variable Transmission              32.0
# 361      Sedan  Continuously Variable Transmission              32.0
#
#     fuel_economy_highway         exterior_color
# 288                 42.0  Modern Steel Metallic
# 173                 42.0  Modern Steel Metallic
# 0                   42.0                   Gray
# 810                 42.0  Lunar Silver Metallic
# 608                 42.0                  Black
# ..                   ...                    ...
# 315                 42.0           Lunar Silver
# 357                 42.0   Cosmic Blue Metallic
# 359                 42.0  Modern Steel Metallic
# 28                  42.0                  White
# 361                 42.0   Platinum White Pearl
#
# [100 rows x 22 columns]

# %%
# Date Handling

def handle_date(data):
    #Extracting Yea
    data['listing_year'] = pd.to_datetime(data['listing_date_begin']).dt.year
    #Extracting Month
    map_month = {1:'Jan', 2:'Feb', 3:'Mar', 
                 4:'Apr', 5:'May', 6:'Jun', 
                 7:'Jul', 8:'Aug', 9:'Sep', 
                 10:'Oct', 11:'Nov', 12:'Dec'}
    data['listing_month'] = pd.to_datetime(data['listing_date_begin']).dt.month.replace(map_month)
    return data

df_date = handle_date(df_impute)

print("Columns: n/{}".format(df_date.columns))
print("Length: {}".format(len(df_date)))
print(df_date.sort_values(["vin", "listing_date_begin"]).head(100))
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'listing_year',
#        'listing_month'],
#       dtype='object')
# Length: 893
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 288  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 173  19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 810  19XFC1F30LE202454         2020-07-14   1500.0             0.0       1
# 608  19XFC1F30LE205208         2021-03-27  18500.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 315  19XFC1F38LE203285         2020-08-15   3575.0             0.0       0
# 357  19XFC1F38LE204386         2020-12-03   4250.0             0.0       1
# 359  19XFC1F38LE207644         2020-09-24   7056.0             0.0       1
# 28   19XFC1F38LE209314         2020-11-26   5449.0             0.0       1
# 361  19XFC1F39LE000387         2020-12-29   7402.0             0.0       1
#
#             seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 288        Santa Fe, NM           NM      DEALER                           1
# 173        Highland, IN           IN      DEALER                           1
# 0             Davie, FL           FL      DEALER                           1
# 810        Portland, OR           OR      DEALER                           1
# 608          Oxnard, CA           CA      DEALER                           0
# ..                  ...          ...         ...                         ...
# 315          Tustin, CA           CA      DEALER                           1
# 357          Fresno, CA           CA      DEALER                           1
# 359       Rockville, MD           MD      DEALER                           1
# 28   Cathedral City, CA           CA      DEALER                           1
# 361         Phoenix, AZ           AZ      DEALER                           1
#
#      seller_is_online_only  ...   make  model          trim body_style  \
# 288                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 173                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 0                        1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 810                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 608                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# ..                     ...  ...    ...    ...           ...        ...
# 315                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 357                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 359                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 28                       1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 361                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
#
#                            transmission fuel_economy_city  \
# 288  Continuously Variable Transmission              32.0
# 173  Continuously Variable Transmission              32.0
# 0    Continuously Variable Transmission              32.0
# 810  Continuously Variable Transmission              32.0
# 608                           Automatic              32.0
# ..                                  ...               ...
# 315  Continuously Variable Transmission              32.0
# 357  Continuously Variable Transmission              32.0
# 359  Continuously Variable Transmission              32.0
# 28   Continuously Variable Transmission              32.0
# 361  Continuously Variable Transmission              32.0
#
#     fuel_economy_highway         exterior_color listing_year  listing_month
# 288                 42.0  Modern Steel Metallic         2021            Apr
# 173                 42.0  Modern Steel Metallic         2021            Apr
# 0                   42.0                   Gray         2021            Feb
# 810                 42.0  Lunar Silver Metallic         2020            Jul
# 608                 42.0                  Black         2021            Mar
# ..                   ...                    ...          ...            ...
# 315                 42.0           Lunar Silver         2020            Aug
# 357                 42.0   Cosmic Blue Metallic         2020            Dec
# 359                 42.0  Modern Steel Metallic         2020            Sep
# 28                  42.0                  White         2020            Nov
# 361                 42.0   Platinum White Pearl         2020            Dec
#
# [100 rows x 24 columns]

# %%
# Split feature with where it makes sense
df_date['seller_city'] = df_date.seller_city.str.split(",").str[0]

# %%
# Handling Outliers

def handle_outliers(data):
    numeric_cols = ['mileage', 'accident_count',
       'fuel_economy_city', 'fuel_economy_highway', 'msrp']
    print(data.describe())
    for col in numeric_cols:
        upper_lim = data[col].quantile(.95)
        lower_lim = data[col].quantile(.05)
        data_out = data[(data[col] < upper_lim) & (data[col] > lower_lim)]
    return data_out

df_outlier = handle_outliers(df_date)

print("Columns: n/{}".format(df_outlier.columns))
print("Length: {}".format(len(df_outlier)))
print(df_outlier.describe())
print(df_outlier.sort_values(["vin", "listing_date_begin"]).head(100))
# Out:
#             mileage  accident_count      is_cpo  seller_is_franchise_dealer  \
# count    893.000000      893.000000  893.000000                  893.000000
# mean    8030.301792        0.038074    0.294513                    0.839866
# std     7038.337654        0.191482    0.456079                    0.366936
# min       56.000000        0.000000    0.000000                    0.000000
# 25%     2754.000000        0.000000    0.000000                    1.000000
# 50%     6273.000000        0.000000    0.000000                    1.000000
# 75%    11473.000000        0.000000    1.000000                    1.000000
# max    66099.500000        1.000000    1.000000                    1.000000
#
#        seller_is_online_only  seller_ships_nationwide           msrp  \
# count             893.000000               893.000000     893.000000
# mean                0.966405                 0.095185   33481.736517
# std                 0.180284                 0.293634   10610.430343
# min                 0.000000                 0.000000   16975.000000
# 25%                 1.000000                 0.000000   26005.000000
# 50%                 1.000000                 0.000000   35495.000000
# 75%                 1.000000                 0.000000   35495.000000
# max                 1.000000                 1.000000  125990.000000
#
#           list_price  fuel_economy_city  fuel_economy_highway  listing_year
# count     893.000000         893.000000            893.000000    893.000000
# mean    28842.389698          29.077268             35.889138   2020.567749
# std     14905.456556          10.970030              7.596836      0.519951
# min     15030.000000          12.000000             18.000000   2019.000000
# 25%     20995.000000          24.000000             31.000000   2020.000000
# 50%     23415.000000          30.000000             38.000000   2021.000000
# 75%     34500.000000          32.000000             42.000000   2021.000000
# max    139000.000000          55.000000             49.000000   2021.000000
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'listing_year',
#        'listing_month'],
#       dtype='object')
# Length: 802
#             mileage  accident_count      is_cpo  seller_is_franchise_dealer  \
# count    802.000000      802.000000  802.000000                  802.000000
# mean    8130.865337        0.038653    0.294264                    0.825436
# std     7105.179487        0.192888    0.455996                    0.379830
# min       56.000000        0.000000    0.000000                    0.000000
# 25%     2767.000000        0.000000    0.000000                    1.000000
# 50%     6324.000000        0.000000    0.000000                    1.000000
# 75%    11660.500000        0.000000    1.000000                    1.000000
# max    66099.500000        1.000000    1.000000                    1.000000
#
#        seller_is_online_only  seller_ships_nationwide          msrp  \
# count             802.000000               802.000000    802.000000
# mean                0.962594                 0.098504  32594.170461
# std                 0.189874                 0.298181   5383.022413
# min                 0.000000                 0.000000  20997.000000
# 25%                 1.000000                 0.000000  27524.250000
# 50%                 1.000000                 0.000000  35495.000000
# 75%                 1.000000                 0.000000  35495.000000
# max                 1.000000                 1.000000  42200.000000
#
#           list_price  fuel_economy_city  fuel_economy_highway  listing_year
# count     802.000000         802.000000            802.000000    802.000000
# mean    27617.396509          29.604738             36.305486   2020.571072
# std     12175.073151          11.114499              7.526869      0.519830
# min     15030.000000          12.000000             18.000000   2019.000000
# 25%     21025.000000          24.000000             31.000000   2020.000000
# 50%     23417.000000          30.000000             38.000000   2021.000000
# 75%     31653.500000          32.000000             42.000000   2021.000000
# max    139000.000000          55.000000             49.000000   2021.000000
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 288  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 173  19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 810  19XFC1F30LE202454         2020-07-14   1500.0             0.0       1
# 608  19XFC1F30LE205208         2021-03-27  18500.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 359  19XFC1F38LE207644         2020-09-24   7056.0             0.0       1
# 28   19XFC1F38LE209314         2020-11-26   5449.0             0.0       1
# 361  19XFC1F39LE000387         2020-12-29   7402.0             0.0       1
# 403  19XFC1F39LE000910         2021-01-04   1200.0             0.0       0
# 401  19XFC1F39LE000910         2021-02-24   2489.0             0.0       0
#
#         seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 288        Santa Fe           NM      DEALER                           1
# 173        Highland           IN      DEALER                           1
# 0             Davie           FL      DEALER                           1
# 810        Portland           OR      DEALER                           1
# 608          Oxnard           CA      DEALER                           0
# ..              ...          ...         ...                         ...
# 359       Rockville           MD      DEALER                           1
# 28   Cathedral City           CA      DEALER                           1
# 361         Phoenix           AZ      DEALER                           1
# 403          Manvel           TX      DEALER                           1
# 401         Houston           TX      DEALER                           1
#
#      seller_is_online_only  ...   make  model          trim body_style  \
# 288                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 173                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 0                        1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 810                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 608                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# ..                     ...  ...    ...    ...           ...        ...
# 359                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 28                       1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 361                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 403                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
# 401                      1  ...  Honda  Civic  EX Sedan FWD      Sedan
#
#                            transmission fuel_economy_city  \
# 288  Continuously Variable Transmission              32.0
# 173  Continuously Variable Transmission              32.0
# 0    Continuously Variable Transmission              32.0
# 810  Continuously Variable Transmission              32.0
# 608                           Automatic              32.0
# ..                                  ...               ...
# 359  Continuously Variable Transmission              32.0
# 28   Continuously Variable Transmission              32.0
# 361  Continuously Variable Transmission              32.0
# 403                           Automatic              32.0
# 401                           Automatic              32.0
#
#     fuel_economy_highway         exterior_color listing_year  listing_month
# 288                 42.0  Modern Steel Metallic         2021            Apr
# 173                 42.0  Modern Steel Metallic         2021            Apr
# 0                   42.0                   Gray         2021            Feb
# 810                 42.0  Lunar Silver Metallic         2020            Jul
# 608                 42.0                  Black         2021            Mar
# ..                   ...                    ...          ...            ...
# 359                 42.0  Modern Steel Metallic         2020            Sep
# 28                  42.0                  White         2020            Nov
# 361                 42.0   Platinum White Pearl         2020            Dec
# 403                 42.0  Lunar Silver Metallic         2021            Jan
# 401                 42.0  Lunar Silver Metallic         2021            Feb
#
# [100 rows x 24 columns]

# %%
# Normalization
def normalize(data):
    numeric_cols = ['mileage', 'accident_count','fuel_economy_city', 'fuel_economy_highway', 'msrp']
    for col in numeric_cols:
        data[col+'_normalized'] = (data[col] - data[col].min()) / (data[col].max() - data[col].min())
    return data

df_norm = normalize(df_outlier)

print("Columns: n/{}".format(df_norm.columns))
print("Length: {}".format(len(df_norm)))
print(df_norm.describe())
print(df_norm.sort_values(["vin", "listing_date_begin"]).head(100))
# Out:
# Columns: n/Index(['index_pandas', 'vin', 'days_on_market', 'listing_date_begin',
#        'listing_date_end', 'year', 'make', 'model', 'trim', 'body_style',
#        'transmission', 'mileage', 'accident_count', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'msrp', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'list_price', 'shift_buyer_region',
#        'mileage_normalized', 'accident_count_normalized',
#        'fuel_economy_city_normalized', 'fuel_economy_highway_normalized',
#        'msrp_normalized'],
#       dtype='object')
# Length: 696656
#         index_pandas  days_on_market           year        mileage  \
# count  696656.000000   696656.000000  696656.000000  668588.000000
# mean   348327.500000       52.542325    2020.087838   14139.197042
# std    201107.408904       65.811119       0.283242   11786.003820
# min         0.000000        0.000000    2020.000000       0.000000
# 25%    174163.750000       11.000000    2020.000000    4470.000000
# 50%    348327.500000       30.000000    2020.000000   10952.000000
# 75%    522491.250000       67.000000    2020.000000   21880.250000
# max    696655.000000      729.000000    2022.000000  364350.000000
#
#        accident_count  fuel_economy_city  fuel_economy_highway           msrp  \
# count   680294.000000      600280.000000          600280.00000  346149.000000
# mean         0.037035          24.647916              31.38980   37771.019547
# std          0.194682           9.271573               8.76608   16163.586393
# min          0.000000          12.000000              17.00000       0.000000
# 25%          0.000000          19.000000              26.00000   26399.000000
# 50%          0.000000          24.000000              31.00000   35505.000000
# 75%          0.000000          28.000000              38.00000   44756.000000
# max          3.000000         127.000000             127.00000  999995.000000
#
#          list_price  mileage_normalized  accident_count_normalized  \
# count  6.628700e+05       668588.000000              680294.000000
# mean   3.433520e+04            0.038807                   0.012345
# std    1.688307e+04            0.032348                   0.064894
# min    2.490000e+02            0.000000                   0.000000
# 25%    2.296900e+04            0.012268                   0.000000
# 50%    3.199400e+04            0.030059                   0.000000
# 75%    4.152700e+04            0.060053                   0.000000
# max    3.649535e+06            1.000000                   1.000000
#
#        fuel_economy_city_normalized  fuel_economy_highway_normalized  \
# count                 600280.000000                    600280.000000
# mean                       0.109982                         0.130816
# std                        0.080622                         0.079692
# min                        0.000000                         0.000000
# 25%                        0.060870                         0.081818
# 50%                        0.104348                         0.127273
# 75%                        0.139130                         0.190909
# max                        1.000000                         1.000000
#
#        msrp_normalized
# count    346149.000000
# mean          0.037771
# std           0.016164
# min           0.000000
# 25%           0.026399
# 50%           0.035505
# 75%           0.044756
# max           1.000000
#        index_pandas                vin  days_on_market listing_date_begin  \
# 57683         57683  0HGCV3F93LA014514               1         2021-02-23
# 8404           8404  19XFC1F30LE000679              28         2021-03-28
# 8405           8405  19XFC1F30LE000679              27         2021-03-28
# 4298           4298  19XFC1F30LE001184              13         2021-01-11
# 4299           4299  19XFC1F30LE001184              12         2021-01-11
# ...             ...                ...             ...                ...
# 4178           4178  19XFC1F30LE205497              29         2021-03-20
# 4179           4179  19XFC1F30LE205497              28         2021-03-20
# 6635           6635  19XFC1F30LE209727               1         2021-04-12
# 16451         16451  19XFC1F30LE211624             316         2020-05-30
# 16452         16452  19XFC1F30LE211624             315         2020-05-30
#
#       listing_date_end  year   make   model          trim body_style  ...  \
# 57683       2021-02-24  2020  Honda  Accord           NaN      Sedan  ...
# 8404        2021-04-25  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 8405        2021-04-24  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 4298        2021-01-24  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 4299        2021-01-23  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# ...                ...   ...    ...     ...           ...        ...  ...
# 4178        2021-04-18  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 4179        2021-04-17  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 6635        2021-04-13  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 16451       2021-04-11  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
# 16452       2021-04-10  2020  Honda   Civic  EX Sedan FWD      Sedan  ...
#
#       seller_is_franchise_dealer  seller_is_online_only  \
# 57683                       True                    NaN
# 8404                        True                    NaN
# 8405                        True                    NaN
# 4298                        True                    NaN
# 4299                        True                    NaN
# ...                          ...                    ...
# 4178                        True                    NaN
# 4179                        True                    NaN
# 6635                        True                    NaN
# 16451                       True                    NaN
# 16452                       True                    NaN
#
#        seller_ships_nationwide  list_price  shift_buyer_region  \
# 57683                      NaN     26595.0              Dallas
# 8404                       NaN     21795.0              Dallas
# 8405                       NaN     21795.0              Dallas
# 4298                       NaN     20959.0                 NaN
# 4299                       NaN     21505.0                 NaN
# ...                        ...         ...                 ...
# 4178                       NaN     20790.0                 NaN
# 4179                       NaN     20990.0                 NaN
# 6635                       NaN         NaN          Sacramento
# 16451                      NaN     20998.0                 NaN
# 16452                      NaN     20998.0                 NaN
#
#       mileage_normalized  accident_count_normalized  \
# 57683           0.020085                        NaN
# 8404            0.067990                        0.0
# 8405            0.067990                        0.0
# 4298            0.059959                        0.0
# 4299            0.059959                        0.0
# ...                  ...                        ...
# 4178            0.036528                        0.0
# 4179            0.036528                        0.0
# 6635            0.052861                        0.0
# 16451           0.010907                        0.0
# 16452           0.010907                        0.0
#
#       fuel_economy_city_normalized fuel_economy_highway_normalized  \
# 57683                          NaN                             NaN
# 8404                      0.173913                        0.227273
# 8405                      0.173913                        0.227273
# 4298                      0.173913                        0.227273
# 4299                      0.173913                        0.227273
# ...                            ...                             ...
# 4178                      0.173913                        0.227273
# 4179                      0.173913                        0.227273
# 6635                      0.173913                        0.227273
# 16451                     0.173913                        0.227273
# 16452                     0.173913                        0.227273
#
#       msrp_normalized
# 57683             NaN
# 8404              NaN
# 8405              NaN
# 4298              NaN
# 4299              NaN
# ...               ...
# 4178         0.025033
# 4179         0.025033
# 6635              NaN
# 16451        0.020998
# 16452        0.020998
#
# [100 rows x 31 columns]

# %%
# One hot encoding
def onehot(data):
    onehot_cols = ['year', 'make', 'model', 'body_style', 'seller_city', 
                   'seller_state', 'seller_type', 'listing_year', 'listing_month']
    df_out = data
    for col in onehot_cols:
        encoded_columns = pd.get_dummies(data[col])
        df_out = df_out.join(encoded_columns).drop(col, axis=1)
    return df_out

df_onehot = onehot(df_norm)
df_onehot.columns

# %%
# Make, model, body_style price

# %%
# Text feature extraction

# %%
df_train = df.drop(['vin','listing_date_begin', 'trim', 'transmission', 'exterior_color'])
df_test = df.drop(['vin','listing_date_begin', 'trim', 'transmission', 'exterior_color'])
