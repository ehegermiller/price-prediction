# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
import statsmodels.api as sm
from datetime import timedelta, datetime

# %%
directory = 'C:\\Users\\Emma Hegermiller\\Git\\price-prediction\\data'


df_train = pd.read_csv(directory + '\\train_initial.csv').drop(columns=['Unnamed: 0'])
df_test = pd.read_csv(directory + '\\test_initial.csv').drop(columns=['Unnamed: 0'])

# %%
# Calculate data values for imputation

imputation_dict = {}

# Get median values for imputation of numeric variables
numeric_cols = ['mileage', 'accident_count',
       'fuel_economy_city', 'fuel_economy_highway', 'msrp']
for col in numeric_cols:
    median = df_train[col].median()
    imputation_dict[col] = median
    
# Get imputation values for boolean variables
boolean_cols = ['is_cpo', 'seller_is_franchise_dealer', 'seller_is_online_only', 'seller_ships_nationwide']
boolean_dict = {}
for col in boolean_cols:
    if len(df_train[df_train[col]==True])==0:
        imputation_dict[col] = True
    if len(df_train[df_train[col]==False])==0:
        imputation_dict[col] = False
    else:
        pass

# Get imputation for categorical variables with majority categies with subcategory counts < 0.1%
categorical_cols = ["trim", "transmission", "exterior_color"]
for col in categorical_cols:
    imputation_dict[col] = 'Other'

print(imputation_dict)
# Out:
# {'mileage': 6054.0, 'accident_count': 0.0, 'fuel_economy_city': 30.0, 'fuel_economy_highway': 38.0, 'msrp': 25075.0, 'is_cpo': False, 'seller_is_franchise_dealer': False, 'seller_is_online_only': True, 'seller_ships_nationwide': False, 'trim': 'Other', 'transmission': 'Other', 'exterior_color': 'Other'}

# %%
# Group by observations to summarize 

def summarize_vin(group1):
    """Summarizes observations using mode for categorical variables and median for numeric variables"""
    if len(group1) > 1:
        for col in group1.columns:
            if group1[col].count() > 1:
                if np.issubdtype(group1[col], np.number):
                    group1[col] = group1[col].median()
                else:
                    group1[col] = group1[col].value_counts().index[0]
    return group1

def groupby_vehicle(data):
    """Groups by vin and summarizes categorical and numberic variables that are considered static vehicle attributes"""
    static_cols = ['vin',
                   'year', 
                   'make', 
                   'model', 
                   'trim', 
                   'body_style', 
                   'transmission', 
                   'fuel_economy_city', 
                   'fuel_economy_highway', 
                   'exterior_color']
    df_out = data.groupby('vin')[static_cols].apply(summarize_vin).drop_duplicates()
    return df_out

def groupby_listing(data):
    """Groups by vin and listing_date_begin. 
    Summarizes categorical and numberic variables that are considered static vehicle attributes"""
    dynamic_cols = ['vin', 
                'listing_date_begin',
                'mileage', 
                'accident_count',
                'is_cpo',
                'seller_city', 
                'seller_state', 
                'seller_type',
                'seller_is_franchise_dealer', 
                'seller_is_online_only',
                'seller_ships_nationwide', 
                'msrp',
                'list_price']
    df_out = data.groupby(['vin', 'listing_date_begin'])[dynamic_cols].apply(summarize_vin).drop_duplicates()
    return df_out
    
def summarize_obs(data):
    df_vehicle = groupby_vehicle(data)
    df_listing = groupby_listing(data)
    df_out = df_listing.join(df_vehicle.set_index("vin"), on="vin")
    return df_out
    
df_tidy = summarize_obs(df_train)

print("Columns: n/{}".format(df_tidy.columns))
print("Length: {}".format(len(df_tidy)))
print(df_tidy.sort_values(["vin", "listing_date_begin"]).head(100))

# Test
df_tidy_test = summarize_obs(df_test)
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color'],
#       dtype='object')
# Length: 887
#                    vin listing_date_begin  mileage  accident_count is_cpo  \
# 140  19XFC1F30LE004389         2021-04-23   6874.0             0.0   True
# 87   19XFC1F30LE004859         2021-04-01   5601.0             0.0   True
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0    NaN
# 14   19XFC1F30LE014498         2021-03-26  14397.0             0.0    NaN
# 285  19XFC1F30LE015490         2021-01-15   2769.0             0.0    NaN
# ..                 ...                ...      ...             ...    ...
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0    NaN
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0    NaN
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0   True
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0   True
# 607  19XFC1F38LE019156         2021-02-10   1264.0             0.0   True
#
#          seller_city seller_state seller_type seller_is_franchise_dealer  \
# 140     Santa Fe, NM           NM      DEALER                       True
# 87      Highland, IN           IN      DEALER                       True
# 0          Davie, FL           FL      DEALER                       True
# 14   Bentonville, AR           AR      DEALER                       True
# 285    Milwaukee, WI           WI      DEALER                        NaN
# ..               ...          ...         ...                        ...
# 147     Savannah, GA           GA      DEALER                       True
# 147     Savannah, GA           GA      DEALER                       True
# 148     Savannah, GA           GA      DEALER                       True
# 148     Savannah, GA           GA      DEALER                       True
# 607       Austin, TX           TX      DEALER                       True
#
#     seller_is_online_only  ... list_price    year   make  model          trim  \
# 140                   NaN  ...    23284.0  2020.0  Honda  Civic  EX Sedan FWD
# 87                    NaN  ...    21977.0  2020.0  Honda  Civic  EX Sedan FWD
# 0                     NaN  ...    20833.0  2020.0  Honda  Civic  EX Sedan FWD
# 14                    NaN  ...    22488.0  2020.0  Honda  Civic  EX Sedan FWD
# 285                 False  ...    22990.0  2020.0  Honda  Civic  EX Sedan FWD
# ..                    ...  ...        ...     ...    ...    ...           ...
# 147                   NaN  ...    21975.0  2020.0  Honda  Civic  EX Sedan FWD
# 147                   NaN  ...    21975.0  2020.0  Honda  Civic  EX Sedan FWD
# 148                   NaN  ...    21975.0  2020.0  Honda  Civic  EX Sedan FWD
# 148                   NaN  ...    21975.0  2020.0  Honda  Civic  EX Sedan FWD
# 607                   NaN  ...    23279.0  2020.0  Honda  Civic  EX Sedan FWD
#
#     body_style                        transmission fuel_economy_city  \
# 140      Sedan  Continuously Variable Transmission              32.0
# 87       Sedan  Continuously Variable Transmission              32.0
# 0        Sedan  Continuously Variable Transmission              32.0
# 14       Sedan                           Automatic              32.0
# 285      Sedan                                 NaN              32.0
# ..         ...                                 ...               ...
# 147      Sedan  Continuously Variable Transmission               NaN
# 147      Sedan  Continuously Variable Transmission              32.0
# 148      Sedan  Continuously Variable Transmission               NaN
# 148      Sedan  Continuously Variable Transmission              32.0
# 607      Sedan  Continuously Variable Transmission              32.0
#
#     fuel_economy_highway         exterior_color
# 140                 42.0  Modern Steel Metallic
# 87                  42.0  Modern Steel Metallic
# 0                   42.0                   Gray
# 14                  42.0   Aegean Blue Metallic
# 285                 42.0                   Gray
# ..                   ...                    ...
# 147                  NaN   Cosmic Blue Metallic
# 147                 42.0   Cosmic Blue Metallic
# 148                  NaN   Cosmic Blue Metallic
# 148                 42.0   Cosmic Blue Metallic
# 607                 42.0   Cosmic Blue Metallic
#
# [100 rows x 22 columns]

# %%
# Impute missing values

def impute_variables(data):
    """
    Use dataset values for imputation of missing variables
    """
    return data.fillna(value=imputation_dict).replace({True:1, False:0})

df_impute = impute_variables(df_tidy)

print("Columns: n/{}".format(df_impute.columns))
print("Length: {}".format(len(df_impute)))
print(df_impute.sort_values(["vin", "listing_date_begin"]).head(100))

# Test
df_impute_test = impute_variables(df_tidy_test)
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color'],
#       dtype='object')
# Length: 887
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 140  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 87   19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 14   19XFC1F30LE014498         2021-03-26  14397.0             0.0       0
# 285  19XFC1F30LE015490         2021-01-15   2769.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 607  19XFC1F38LE019156         2021-02-10   1264.0             0.0       1
#
#          seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 140     Santa Fe, NM           NM      DEALER                           1
# 87      Highland, IN           IN      DEALER                           1
# 0          Davie, FL           FL      DEALER                           1
# 14   Bentonville, AR           AR      DEALER                           1
# 285    Milwaukee, WI           WI      DEALER                           0
# ..               ...          ...         ...                         ...
# 147     Savannah, GA           GA      DEALER                           1
# 147     Savannah, GA           GA      DEALER                           1
# 148     Savannah, GA           GA      DEALER                           1
# 148     Savannah, GA           GA      DEALER                           1
# 607       Austin, TX           TX      DEALER                           1
#
#      seller_is_online_only  ...  list_price    year   make  model  \
# 140                      1  ...     23284.0  2020.0  Honda  Civic
# 87                       1  ...     21977.0  2020.0  Honda  Civic
# 0                        1  ...     20833.0  2020.0  Honda  Civic
# 14                       1  ...     22488.0  2020.0  Honda  Civic
# 285                      0  ...     22990.0  2020.0  Honda  Civic
# ..                     ...  ...         ...     ...    ...    ...
# 147                      1  ...     21975.0  2020.0  Honda  Civic
# 147                      1  ...     21975.0  2020.0  Honda  Civic
# 148                      1  ...     21975.0  2020.0  Honda  Civic
# 148                      1  ...     21975.0  2020.0  Honda  Civic
# 607                      1  ...     23279.0  2020.0  Honda  Civic
#
#              trim body_style                        transmission  \
# 140  EX Sedan FWD      Sedan  Continuously Variable Transmission
# 87   EX Sedan FWD      Sedan  Continuously Variable Transmission
# 0    EX Sedan FWD      Sedan  Continuously Variable Transmission
# 14   EX Sedan FWD      Sedan                           Automatic
# 285  EX Sedan FWD      Sedan                               Other
# ..            ...        ...                                 ...
# 147  EX Sedan FWD      Sedan  Continuously Variable Transmission
# 147  EX Sedan FWD      Sedan  Continuously Variable Transmission
# 148  EX Sedan FWD      Sedan  Continuously Variable Transmission
# 148  EX Sedan FWD      Sedan  Continuously Variable Transmission
# 607  EX Sedan FWD      Sedan  Continuously Variable Transmission
#
#     fuel_economy_city fuel_economy_highway         exterior_color
# 140              32.0                 42.0  Modern Steel Metallic
# 87               32.0                 42.0  Modern Steel Metallic
# 0                32.0                 42.0                   Gray
# 14               32.0                 42.0   Aegean Blue Metallic
# 285              32.0                 42.0                   Gray
# ..                ...                  ...                    ...
# 147              30.0                 38.0   Cosmic Blue Metallic
# 147              32.0                 42.0   Cosmic Blue Metallic
# 148              30.0                 38.0   Cosmic Blue Metallic
# 148              32.0                 42.0   Cosmic Blue Metallic
# 607              32.0                 42.0   Cosmic Blue Metallic
#
# [100 rows x 22 columns]

# %%
# Date Handling

def handle_date(data):
    #Extracting Yea
    data['listing_year'] = pd.to_datetime(data['listing_date_begin']).dt.year
    #Extracting Month
    map_month = {1:'Jan', 2:'Feb', 3:'Mar', 
                 4:'Apr', 5:'May', 6:'Jun', 
                 7:'Jul', 8:'Aug', 9:'Sep', 
                 10:'Oct', 11:'Nov', 12:'Dec'}
    data['listing_month'] = pd.to_datetime(data['listing_date_begin']).dt.month.replace(map_month)
    return data

df_date = handle_date(df_impute)

print("Columns: n/{}".format(df_date.columns))
print("Length: {}".format(len(df_date)))
print(df_date.sort_values(["vin", "listing_date_begin"]).head(100))

# Test
df_date_test = handle_date(df_impute_test)
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'listing_year',
#        'listing_month'],
#       dtype='object')
# Length: 887
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 140  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 87   19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 14   19XFC1F30LE014498         2021-03-26  14397.0             0.0       0
# 285  19XFC1F30LE015490         2021-01-15   2769.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 607  19XFC1F38LE019156         2021-02-10   1264.0             0.0       1
#
#          seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 140     Santa Fe, NM           NM      DEALER                           1
# 87      Highland, IN           IN      DEALER                           1
# 0          Davie, FL           FL      DEALER                           1
# 14   Bentonville, AR           AR      DEALER                           1
# 285    Milwaukee, WI           WI      DEALER                           0
# ..               ...          ...         ...                         ...
# 147     Savannah, GA           GA      DEALER                           1
# 147     Savannah, GA           GA      DEALER                           1
# 148     Savannah, GA           GA      DEALER                           1
# 148     Savannah, GA           GA      DEALER                           1
# 607       Austin, TX           TX      DEALER                           1
#
#      seller_is_online_only  ...   make  model          trim  body_style  \
# 140                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 87                       1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 0                        1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 14                       1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 285                      0  ...  Honda  Civic  EX Sedan FWD       Sedan
# ..                     ...  ...    ...    ...           ...         ...
# 147                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 147                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 148                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 148                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 607                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
#
#                            transmission fuel_economy_city  \
# 140  Continuously Variable Transmission              32.0
# 87   Continuously Variable Transmission              32.0
# 0    Continuously Variable Transmission              32.0
# 14                            Automatic              32.0
# 285                               Other              32.0
# ..                                  ...               ...
# 147  Continuously Variable Transmission              30.0
# 147  Continuously Variable Transmission              32.0
# 148  Continuously Variable Transmission              30.0
# 148  Continuously Variable Transmission              32.0
# 607  Continuously Variable Transmission              32.0
#
#     fuel_economy_highway         exterior_color listing_year  listing_month
# 140                 42.0  Modern Steel Metallic         2021            Apr
# 87                  42.0  Modern Steel Metallic         2021            Apr
# 0                   42.0                   Gray         2021            Feb
# 14                  42.0   Aegean Blue Metallic         2021            Mar
# 285                 42.0                   Gray         2021            Jan
# ..                   ...                    ...          ...            ...
# 147                 38.0   Cosmic Blue Metallic         2020            Dec
# 147                 42.0   Cosmic Blue Metallic         2020            Dec
# 148                 38.0   Cosmic Blue Metallic         2020            Dec
# 148                 42.0   Cosmic Blue Metallic         2020            Dec
# 607                 42.0   Cosmic Blue Metallic         2021            Feb
#
# [100 rows x 24 columns]

# %%
# Split features with where it makes sense
df_date['seller_city'] = df_date.seller_city.str.split(",").str[0]

# Test
df_date_test['seller_city'] = df_date_test.seller_city.str.split(",").str[0]

# %%
# Handling Outliers

def handle_outliers(data):
    numeric_cols = ['mileage', 'accident_count',
       'fuel_economy_city', 'fuel_economy_highway', 'msrp']
    print(data.describe())
    for col in numeric_cols:
        upper_lim = data[col].quantile(.95)
        lower_lim = data[col].quantile(.05)
        data_out = data[(data[col] < upper_lim) & (data[col] > lower_lim)]
    return data_out

df_outlier = handle_outliers(df_date)

print("Columns: n/{}".format(df_outlier.columns))
print("Length: {}".format(len(df_outlier)))
print(df_outlier.describe())
print(df_outlier.sort_values(["vin", "listing_date_begin"]).head(100))

# Test
df_outlier_test = handle_outliers(df_date_test)
# Out:
#             mileage  accident_count      is_cpo  seller_is_franchise_dealer  \
# count    887.000000      887.000000  887.000000                  887.000000
# mean    7923.157835        0.032694    0.301015                    0.830891
# std     7334.233183        0.177936    0.458958                    0.375060
# min       56.000000        0.000000    0.000000                    0.000000
# 25%     2740.000000        0.000000    0.000000                    1.000000
# 50%     6054.000000        0.000000    0.000000                    1.000000
# 75%    10902.500000        0.000000    1.000000                    1.000000
# max    66099.500000        1.000000    1.000000                    1.000000
#
#        seller_is_online_only  seller_ships_nationwide           msrp  \
# count             887.000000               887.000000     887.000000
# mean                0.958286                 0.094701   27555.648782
# std                 0.200047                 0.292967   10377.321878
# min                 0.000000                 0.000000   17650.000000
# 25%                 1.000000                 0.000000   25075.000000
# 50%                 1.000000                 0.000000   25075.000000
# 75%                 1.000000                 0.000000   25075.000000
# max                 1.000000                 1.000000  125990.000000
#
#           list_price         year  fuel_economy_city  fuel_economy_highway  \
# count     887.000000   887.000000         887.000000            887.000000
# mean    28993.632469  2020.032694          29.854566             36.703495
# std     15277.157298     0.177936          11.009704              7.516274
# min     16400.000000  2020.000000          12.000000             18.000000
# 25%     20996.500000  2020.000000          29.000000             37.000000
# 50%     23468.000000  2020.000000          30.000000             38.000000
# 75%     34691.500000  2020.000000          32.000000             42.000000
# max    139000.000000  2021.000000          55.000000             49.000000
#
#        listing_year
# count    887.000000
# mean    2020.577227
# std        0.514420
# min     2019.000000
# 25%     2020.000000
# 50%     2021.000000
# 75%     2021.000000
# max     2021.000000
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'listing_year',
#        'listing_month'],
#       dtype='object')
# Length: 797
#             mileage  accident_count      is_cpo  seller_is_franchise_dealer  \
# count    797.000000      797.000000  797.000000                  797.000000
# mean    7998.853827        0.035132    0.299875                    0.814304
# std     7276.293155        0.184228    0.458491                    0.389106
# min       56.000000        0.000000    0.000000                    0.000000
# 25%     2808.000000        0.000000    0.000000                    1.000000
# 50%     6054.000000        0.000000    0.000000                    1.000000
# 75%    11090.000000        0.000000    1.000000                    1.000000
# max    66099.500000        1.000000    1.000000                    1.000000
#
#        seller_is_online_only  seller_ships_nationwide          msrp  \
# count             797.000000               797.000000    797.000000
# mean                0.953576                 0.097867  26072.753413
# std                 0.210534                 0.297321   4020.166296
# min                 0.000000                 0.000000  20997.000000
# 25%                 1.000000                 0.000000  25075.000000
# 50%                 1.000000                 0.000000  25075.000000
# 75%                 1.000000                 0.000000  25075.000000
# max                 1.000000                 1.000000  42667.000000
#
#           list_price         year  fuel_economy_city  fuel_economy_highway  \
# count     797.000000   797.000000         797.000000            797.000000
# mean    27868.237139  2020.033877          30.281054             37.036386
# std     13036.039809     0.181026          11.103586              7.454337
# min     16400.000000  2020.000000          12.000000             18.000000
# 25%     21303.000000  2020.000000          29.000000             37.000000
# 50%     23468.000000  2020.000000          30.000000             38.000000
# 75%     29995.000000  2020.000000          32.000000             42.000000
# max    139000.000000  2021.000000          55.000000             49.000000
#
#        listing_year
# count    797.000000
# mean    2020.573400
# std        0.514801
# min     2019.000000
# 25%     2020.000000
# 50%     2021.000000
# 75%     2021.000000
# max     2021.000000
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 140  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 87   19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 14   19XFC1F30LE014498         2021-03-26  14397.0             0.0       0
# 285  19XFC1F30LE015490         2021-01-15   2769.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 607  19XFC1F38LE019156         2021-02-10   1264.0             0.0       1
# 170  19XFC1F38LE022705         2021-03-10   1730.0             0.0       1
#
#      seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 140     Santa Fe           NM      DEALER                           1
# 87      Highland           IN      DEALER                           1
# 0          Davie           FL      DEALER                           1
# 14   Bentonville           AR      DEALER                           1
# 285    Milwaukee           WI      DEALER                           0
# ..           ...          ...         ...                         ...
# 147     Savannah           GA      DEALER                           1
# 148     Savannah           GA      DEALER                           1
# 148     Savannah           GA      DEALER                           1
# 607       Austin           TX      DEALER                           1
# 170  San Antonio           TX      DEALER                           1
#
#      seller_is_online_only  ...   make  model          trim  body_style  \
# 140                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 87                       1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 0                        1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 14                       1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 285                      0  ...  Honda  Civic  EX Sedan FWD       Sedan
# ..                     ...  ...    ...    ...           ...         ...
# 147                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 148                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 148                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 607                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
# 170                      1  ...  Honda  Civic  EX Sedan FWD       Sedan
#
#                            transmission fuel_economy_city  \
# 140  Continuously Variable Transmission              32.0
# 87   Continuously Variable Transmission              32.0
# 0    Continuously Variable Transmission              32.0
# 14                            Automatic              32.0
# 285                               Other              32.0
# ..                                  ...               ...
# 147  Continuously Variable Transmission              32.0
# 148  Continuously Variable Transmission              30.0
# 148  Continuously Variable Transmission              32.0
# 607  Continuously Variable Transmission              32.0
# 170  Continuously Variable Transmission              32.0
#
#     fuel_economy_highway         exterior_color listing_year  listing_month
# 140                 42.0  Modern Steel Metallic         2021            Apr
# 87                  42.0  Modern Steel Metallic         2021            Apr
# 0                   42.0                   Gray         2021            Feb
# 14                  42.0   Aegean Blue Metallic         2021            Mar
# 285                 42.0                   Gray         2021            Jan
# ..                   ...                    ...          ...            ...
# 147                 42.0   Cosmic Blue Metallic         2020            Dec
# 148                 38.0   Cosmic Blue Metallic         2020            Dec
# 148                 42.0   Cosmic Blue Metallic         2020            Dec
# 607                 42.0   Cosmic Blue Metallic         2021            Feb
# 170                 42.0    Crystal Black Pearl         2021            Mar
#
# [100 rows x 24 columns]
#             mileage  accident_count      is_cpo  seller_is_franchise_dealer  \
# count    840.000000      840.000000  840.000000                  840.000000
# mean    9597.550595        0.035714    0.234524                    0.717857
# std     8062.972810        0.191999    0.423953                    0.450311
# min       71.000000        0.000000    0.000000                    0.000000
# 25%     3201.750000        0.000000    0.000000                    0.000000
# 50%     7389.000000        0.000000    0.000000                    1.000000
# 75%    13833.500000        0.000000    0.000000                    1.000000
# max    48383.000000        2.000000    1.000000                    1.000000
#
#        seller_is_online_only  seller_ships_nationwide           msrp  \
# count             840.000000               840.000000     840.000000
# mean                0.855952                 0.085714   29457.744643
# std                 0.351347                 0.280108   10863.460668
# min                 0.000000                 0.000000     545.000000
# 25%                 1.000000                 0.000000   25075.000000
# 50%                 1.000000                 0.000000   25075.000000
# 75%                 1.000000                 0.000000   34780.000000
# max                 1.000000                 1.000000  109874.000000
#
#           list_price         year  fuel_economy_city  fuel_economy_highway  \
# count     840.000000   840.000000         840.000000            840.000000
# mean    30303.648810  2020.016667          28.142857             35.664286
# std     15823.567432     0.128095           9.578753              7.020558
# min     13950.000000  2020.000000          12.000000             18.000000
# 25%     21895.500000  2020.000000          21.000000             32.000000
# 50%     25097.000000  2020.000000          30.000000             38.000000
# 75%     33423.500000  2020.000000          30.000000             38.000000
# max    129900.000000  2021.000000          55.000000             49.000000
#
#        listing_year
# count    840.000000
# mean    2020.554762
# std        0.509131
# min     2019.000000
# 25%     2020.000000
# 50%     2021.000000
# 75%     2021.000000
# max     2021.000000

# %%
# Normalization
def normalize(data):
    numeric_cols = ['mileage', 'accident_count','fuel_economy_city', 'fuel_economy_highway', 'msrp']
    for col in numeric_cols:
        data[col+'_normalized'] = (data[col] - data[col].min()) / (data[col].max() - data[col].min())
    return data

df_norm = normalize(df_outlier)

print("Columns: n/{}".format(df_norm.columns))
print("Length: {}".format(len(df_norm)))
print(df_norm.describe())
print(df_norm.sort_values(["vin", "listing_date_begin"]).head(100))

# Test
df_norm_test = normalize(df_outlier_test)
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_city', 'seller_state', 'seller_type',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price', 'year', 'make',
#        'model', 'trim', 'body_style', 'transmission', 'fuel_economy_city',
#        'fuel_economy_highway', 'exterior_color', 'listing_year',
#        'listing_month', 'mileage_normalized', 'accident_count_normalized',
#        'fuel_economy_city_normalized', 'fuel_economy_highway_normalized',
#        'msrp_normalized'],
#       dtype='object')
# Length: 797
#             mileage  accident_count      is_cpo  seller_is_franchise_dealer  \
# count    797.000000      797.000000  797.000000                  797.000000
# mean    7998.853827        0.035132    0.299875                    0.814304
# std     7276.293155        0.184228    0.458491                    0.389106
# min       56.000000        0.000000    0.000000                    0.000000
# 25%     2808.000000        0.000000    0.000000                    1.000000
# 50%     6054.000000        0.000000    0.000000                    1.000000
# 75%    11090.000000        0.000000    1.000000                    1.000000
# max    66099.500000        1.000000    1.000000                    1.000000
#
#        seller_is_online_only  seller_ships_nationwide          msrp  \
# count             797.000000               797.000000    797.000000
# mean                0.953576                 0.097867  26072.753413
# std                 0.210534                 0.297321   4020.166296
# min                 0.000000                 0.000000  20997.000000
# 25%                 1.000000                 0.000000  25075.000000
# 50%                 1.000000                 0.000000  25075.000000
# 75%                 1.000000                 0.000000  25075.000000
# max                 1.000000                 1.000000  42667.000000
#
#           list_price         year  fuel_economy_city  fuel_economy_highway  \
# count     797.000000   797.000000         797.000000            797.000000
# mean    27868.237139  2020.033877          30.281054             37.036386
# std     13036.039809     0.181026          11.103586              7.454337
# min     16400.000000  2020.000000          12.000000             18.000000
# 25%     21303.000000  2020.000000          29.000000             37.000000
# 50%     23468.000000  2020.000000          30.000000             38.000000
# 75%     29995.000000  2020.000000          32.000000             42.000000
# max    139000.000000  2021.000000          55.000000             49.000000
#
#        listing_year  mileage_normalized  accident_count_normalized  \
# count    797.000000          797.000000                 797.000000
# mean    2020.573400            0.120267                   0.035132
# std        0.514801            0.110174                   0.184228
# min     2019.000000            0.000000                   0.000000
# 25%     2020.000000            0.041670                   0.000000
# 50%     2021.000000            0.090819                   0.000000
# 75%     2021.000000            0.167072                   0.000000
# max     2021.000000            1.000000                   1.000000
#
#        fuel_economy_city_normalized  fuel_economy_highway_normalized  \
# count                    797.000000                       797.000000
# mean                       0.425141                         0.614077
# std                        0.258223                         0.240462
# min                        0.000000                         0.000000
# 25%                        0.395349                         0.612903
# 50%                        0.418605                         0.645161
# 75%                        0.465116                         0.774194
# max                        1.000000                         1.000000
#
#        msrp_normalized
# count       797.000000
# mean          0.234230
# std           0.185518
# min           0.000000
# 25%           0.188186
# 50%           0.188186
# 75%           0.188186
# max           1.000000
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 140  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 87   19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 14   19XFC1F30LE014498         2021-03-26  14397.0             0.0       0
# 285  19XFC1F30LE015490         2021-01-15   2769.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 148  19XFC1F38LE006505         2020-12-27   9334.5             0.0       1
# 607  19XFC1F38LE019156         2021-02-10   1264.0             0.0       1
# 170  19XFC1F38LE022705         2021-03-10   1730.0             0.0       1
#
#      seller_city seller_state seller_type  seller_is_franchise_dealer  \
# 140     Santa Fe           NM      DEALER                           1
# 87      Highland           IN      DEALER                           1
# 0          Davie           FL      DEALER                           1
# 14   Bentonville           AR      DEALER                           1
# 285    Milwaukee           WI      DEALER                           0
# ..           ...          ...         ...                         ...
# 147     Savannah           GA      DEALER                           1
# 148     Savannah           GA      DEALER                           1
# 148     Savannah           GA      DEALER                           1
# 607       Austin           TX      DEALER                           1
# 170  San Antonio           TX      DEALER                           1
#
#      seller_is_online_only  ...  fuel_economy_city  fuel_economy_highway  \
# 140                      1  ...               32.0                  42.0
# 87                       1  ...               32.0                  42.0
# 0                        1  ...               32.0                  42.0
# 14                       1  ...               32.0                  42.0
# 285                      0  ...               32.0                  42.0
# ..                     ...  ...                ...                   ...
# 147                      1  ...               32.0                  42.0
# 148                      1  ...               30.0                  38.0
# 148                      1  ...               32.0                  42.0
# 607                      1  ...               32.0                  42.0
# 170                      1  ...               32.0                  42.0
#
#             exterior_color  listing_year listing_month mileage_normalized  \
# 140  Modern Steel Metallic          2021           Apr           0.103235
# 87   Modern Steel Metallic          2021           Apr           0.083960
# 0                     Gray          2021           Feb           0.028284
# 14    Aegean Blue Metallic          2021           Mar           0.217145
# 285                   Gray          2021           Jan           0.041079
# ..                     ...           ...           ...                ...
# 147   Cosmic Blue Metallic          2020           Dec           0.140491
# 148   Cosmic Blue Metallic          2020           Dec           0.140491
# 148   Cosmic Blue Metallic          2020           Dec           0.140491
# 607   Cosmic Blue Metallic          2021           Feb           0.018291
# 170    Crystal Black Pearl          2021           Mar           0.025347
#
#     accident_count_normalized fuel_economy_city_normalized  \
# 140                       0.0                     0.465116
# 87                        0.0                     0.465116
# 0                         0.0                     0.465116
# 14                        0.0                     0.465116
# 285                       0.0                     0.465116
# ..                        ...                          ...
# 147                       0.0                     0.465116
# 148                       0.0                     0.418605
# 148                       0.0                     0.465116
# 607                       0.0                     0.465116
# 170                       0.0                     0.465116
#
#     fuel_economy_highway_normalized  msrp_normalized
# 140                        0.774194         0.138533
# 87                         0.774194         0.188186
# 0                          0.774194         0.188186
# 14                         0.774194         0.188186
# 285                        0.774194         0.188186
# ..                              ...              ...
# 147                        0.774194         0.080203
# 148                        0.645161         0.080203
# 148                        0.774194         0.080203
# 607                        0.774194         0.188186
# 170                        0.774194         0.188186
#
# [100 rows x 29 columns]
# C:\Users\EMMAHE~1\AppData\Local\Temp/ipykernel_22964/1153022590.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col+'_normalized'] = (data[col] - data[col].min()) / (data[col].max() - data[col].min())
# C:\Users\EMMAHE~1\AppData\Local\Temp/ipykernel_22964/1153022590.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col+'_normalized'] = (data[col] - data[col].min()) / (data[col].max() - data[col].min())

# %%
# One hot encoding
def onehot(data):
    onehot_cols = ['year', 'make', 'model', 'body_style', 'seller_city', 
                   'seller_state', 'seller_type', 'listing_year', 'listing_month']
    df_out = data
    for col in onehot_cols:
        encoded_columns = pd.get_dummies(data[col], prefix=col)
        df_out = df_out.join(encoded_columns).drop(col, axis=1)
    return df_out

df_onehot = onehot(df_norm)

print("Columns: n/{}".format(df_onehot.columns))
print("Length: {}".format(len(df_onehot)))
print(df_onehot.sort_values(["vin", "listing_date_begin"]).head(100))

# Test
df_onehot_test = onehot(df_norm_test)
# Out:
# Columns: n/Index(['vin', 'listing_date_begin', 'mileage', 'accident_count', 'is_cpo',
#        'seller_is_franchise_dealer', 'seller_is_online_only',
#        'seller_ships_nationwide', 'msrp', 'list_price',
#        ...
#        'listing_month_Dec', 'listing_month_Feb', 'listing_month_Jan',
#        'listing_month_Jul', 'listing_month_Jun', 'listing_month_Mar',
#        'listing_month_May', 'listing_month_Nov', 'listing_month_Oct',
#        'listing_month_Sep'],
#       dtype='object', length=496)
# Length: 22259
#                    vin listing_date_begin  mileage  accident_count  is_cpo  \
# 140  19XFC1F30LE004389         2021-04-23   6874.0             0.0       1
# 87   19XFC1F30LE004859         2021-04-01   5601.0             0.0       1
# 0    19XFC1F30LE007261         2021-02-10   1924.0             0.0       0
# 14   19XFC1F30LE014498         2021-03-26  14397.0             0.0       0
# 285  19XFC1F30LE015490         2021-01-15   2769.0             0.0       0
# ..                 ...                ...      ...             ...     ...
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
# 147  19XFC1F38LE006505         2020-12-27   9334.5             0.0       0
#
#      seller_is_franchise_dealer  seller_is_online_only  \
# 140                           1                      1
# 87                            1                      1
# 0                             1                      1
# 14                            1                      1
# 285                           0                      0
# ..                          ...                    ...
# 147                           1                      1
# 147                           1                      1
# 147                           1                      1
# 147                           1                      1
# 147                           1                      1
#
#      seller_ships_nationwide     msrp  list_price  ... listing_month_Dec  \
# 140                        0  23999.0     23284.0  ...                 0
# 87                         0  25075.0     21977.0  ...                 0
# 0                          0  25075.0     20833.0  ...                 0
# 14                         0  25075.0     22488.0  ...                 0
# 285                        1  25075.0     22990.0  ...                 0
# ..                       ...      ...         ...  ...               ...
# 147                        0  22735.0     21975.0  ...                 1
# 147                        0  22735.0     21975.0  ...                 1
# 147                        0  22735.0     21975.0  ...                 1
# 147                        0  22735.0     21975.0  ...                 1
# 147                        0  22735.0     21975.0  ...                 1
#
#     listing_month_Feb  listing_month_Jan  listing_month_Jul listing_month_Jun  \
# 140                 0                  0                  0                 0
# 87                  0                  0                  0                 0
# 0                   1                  0                  0                 0
# 14                  0                  0                  0                 0
# 285                 0                  1                  0                 0
# ..                ...                ...                ...               ...
# 147                 0                  0                  0                 0
# 147                 0                  0                  0                 0
# 147                 0                  0                  0                 0
# 147                 0                  0                  0                 0
# 147                 0                  0                  0                 0
#
#      listing_month_Mar  listing_month_May  listing_month_Nov  \
# 140                  0                  0                  0
# 87                   0                  0                  0
# 0                    0                  0                  0
# 14                   1                  0                  0
# 285                  0                  0                  0
# ..                 ...                ...                ...
# 147                  0                  0                  0
# 147                  0                  0                  0
# 147                  0                  0                  0
# 147                  0                  0                  0
# 147                  0                  0                  0
#
#      listing_month_Oct  listing_month_Sep
# 140                  0                  0
# 87                   0                  0
# 0                    0                  0
# 14                   0                  0
# 285                  0                  0
# ..                 ...                ...
# 147                  0                  0
# 147                  0                  0
# 147                  0                  0
# 147                  0                  0
# 147                  0                  0
#
# [100 rows x 496 columns]

# %%
# Make, model, body_style price

# %%
# Text feature extraction
# # vectorizing trim
# vectorizer = TfidfVectorizer(ngram_range=(1, 3), min_df=3, max_features=250000)

# train_trim_tfidf = vectorizer.fit_transform(['trim'])
# # test_trim_tfidf = vectorizer.transform(test['trim'])


# # vectorixing transmission
# vectorizer = TfidfVectorizer(ngram_range=(1, 3), min_df=5, max_features=500000)

# train_transmission_tfidf = vectorizer.fit_transform(train_df['transmission'])
# # test_transmission_tfidf = vectorizer.transform(test['transmission'])

# # vectorixing exterior_color
# vectorizer = TfidfVectorizer(ngram_range=(1, 3), min_df=5, max_features=500000)

# train_exterior_color_tfidf = vectorizer.fit_transform(train_df['exterior_color'])
# # test_exterior_color_tfidf = vectorizer.transform(test['exterior_color'])

# %%
df_train_final = df_onehot.drop(columns=['vin','listing_date_begin', 'trim', 'transmission', 'exterior_color'])
df_test_final = df_onehot_test.drop(columns=['vin','listing_date_begin', 'trim', 'transmission', 'exterior_color'])

# %%
# Confirm no missing values 
# Train
row_total = len(df_train_final)
for col in df_train_final.columns:
    if df_train_final[col].isna().sum()/row_total > 0:
        print(df_train_final[col].isna().sum()/row_total)
    else:
        pass

# Test
row_total_test = len(df_test_final)
for col in df_test_final.columns:
    if df_test_final[col].isna().sum()/row_total_test > 0:
        print(df_test_final[col].isna().sum()/row_total_test)
    else:
        pass

# %%
# Confirm no categorical variables
# Train
pd.set_option('display.max_rows', 500)
df_train_final.dtypes

# Test
print(df_test_final.dtypes)
# Out:
# mileage                             float64
# accident_count                      float64
# is_cpo                                int64
# seller_is_franchise_dealer            int64
# seller_is_online_only                 int64
# seller_ships_nationwide               int64
# msrp                                float64
# list_price                          float64
# fuel_economy_city                   float64
# fuel_economy_highway                float64
# mileage_normalized                  float64
# accident_count_normalized           float64
# fuel_economy_city_normalized        float64
# fuel_economy_highway_normalized     float64
# msrp_normalized                     float64
# year_2020.0                           uint8
# year_2021.0                           uint8
# make_Ford                             uint8
# make_Honda                            uint8
# model_Civic                           uint8
# model_Explorer                        uint8
# model_Insight                         uint8
# model_Mustang                         uint8
# model_Mustang Shelby GT350            uint8
# model_Mustang Shelby GT500            uint8
# model_Transit Passenger               uint8
# body_style_Convertible                uint8
# body_style_Coupe                      uint8
# body_style_SUV / Crossover            uint8
# body_style_Sedan                      uint8
# body_style_Van                        uint8
# seller_city_Addison                   uint8
# seller_city_Aiken                     uint8
# seller_city_Akron                     uint8
# seller_city_Albuquerque               uint8
# seller_city_Amarillo                  uint8
# seller_city_American Fork             uint8
# seller_city_Americus                  uint8
# seller_city_Ankeny                    uint8
# seller_city_Ann Arbor                 uint8
# seller_city_Apex                      uint8
# seller_city_Apple Valley              uint8
# seller_city_Arlington                 uint8
# seller_city_Arlington Heights         uint8
# seller_city_Ashland                   uint8
# seller_city_Athens                    uint8
# seller_city_Atlanta                   uint8
# seller_city_Augusta                   uint8
# seller_city_Aurora                    uint8
# seller_city_Austin                    uint8
# seller_city_Avon                      uint8
# seller_city_Avondale                  uint8
# seller_city_Bakersfield               uint8
# seller_city_Baltimore                 uint8
# seller_city_Barkhamsted               uint8
# seller_city_Bartow                    uint8
# seller_city_Baton Rouge               uint8
# seller_city_Beaumont                  uint8
# seller_city_Beckley                   uint8
# seller_city_Bellevue                  uint8
# seller_city_Bellingham                uint8
# seller_city_Berkeley                  uint8
# seller_city_Bessemer                  uint8
# seller_city_Birmingham                uint8
# seller_city_Blackfoot                 uint8
# seller_city_Bloomington               uint8
# seller_city_Bluffton                  uint8
# seller_city_Bowie                     uint8
# seller_city_Bowling Green             uint8
# seller_city_Bradenton                 uint8
# seller_city_Brandon                   uint8
# seller_city_Brick                     uint8
# seller_city_Buena Park                uint8
# seller_city_Buffalo                   uint8
# seller_city_Buford                    uint8
# seller_city_Burbank                   uint8
# seller_city_Burlingame                uint8
# seller_city_Burlington Township       uint8
# seller_city_Butler                    uint8
# seller_city_Byron                     uint8
# seller_city_Carson                    uint8
# seller_city_Cary                      uint8
# seller_city_Casa Grande               uint8
# seller_city_Cathedral City            uint8
# seller_city_Cave City                 uint8
# seller_city_Cerritos                  uint8
# seller_city_Chamblee                  uint8
# seller_city_Chandler                  uint8
# seller_city_Charleston                uint8
# seller_city_Charlotte                 uint8
# seller_city_Chattanooga               uint8
# seller_city_Cheney                    uint8
# seller_city_Cincinnati                uint8
# seller_city_Clear Lake                uint8
# seller_city_Cleveland                 uint8
# seller_city_Coconut Creek             uint8
# seller_city_College Station           uint8
# seller_city_Colorado Springs          uint8
# seller_city_Columbus                  uint8
# seller_city_Concord                   uint8
# seller_city_Corpus Christi            uint8
# seller_city_Crosby                    uint8
# seller_city_Crossville                uint8
# seller_city_Croton-On-Hudson          uint8
# seller_city_Culver City               uint8
# seller_city_Dade City                 uint8
# seller_city_Dallas                    uint8
# seller_city_Dandridge                 uint8
# seller_city_Danvers                   uint8
# seller_city_Daphne                    uint8
# seller_city_Davenport                 uint8
# seller_city_Davie                     uint8
# seller_city_Daytona Beach             uint8
# seller_city_Delavan                   uint8
# seller_city_Delaware                  uint8
# seller_city_Denham Springs            uint8
# seller_city_Denton                    uint8
# seller_city_Denver                    uint8
# seller_city_Devine                    uint8
# seller_city_Dillsburg                 uint8
# seller_city_Draper                    uint8
# seller_city_Dublin                    uint8
# seller_city_Duluth                    uint8
# seller_city_Eatontown                 uint8
# seller_city_Eden Prairie              uint8
# seller_city_El Paso                   uint8
# seller_city_Elk Grove                 uint8
# seller_city_Elyria                    uint8
# seller_city_Enterprise                uint8
# seller_city_Erie                      uint8
# seller_city_Evansville                uint8
# seller_city_Fairfield                 uint8
# seller_city_Falls Church              uint8
# seller_city_Fallston                  uint8
# seller_city_Farmington                uint8
# seller_city_Farmington Hills          uint8
# seller_city_Fayetteville              uint8
# seller_city_Fergus Falls              uint8
# seller_city_Fletcher                  uint8
# seller_city_Florence                  uint8
# seller_city_Folsom                    uint8
# seller_city_Fontana                   uint8
# seller_city_Fort Collins              uint8
# seller_city_Fort Lauderdale           uint8
# seller_city_Fort Myers                uint8
# seller_city_Fort Worth                uint8
# seller_city_Frankfort                 uint8
# seller_city_Franklin                  uint8
# seller_city_Frederick                 uint8
# seller_city_Fremont                   uint8
# seller_city_Fresno                    uint8
# seller_city_Gainesville               uint8
# seller_city_Gilbert                   uint8
# seller_city_Gladstone                 uint8
# seller_city_Glen Burnie               uint8
# seller_city_Goldsboro                 uint8
# seller_city_Gower                     uint8
# seller_city_Granbury                  uint8
# seller_city_Grapevine                 uint8
# seller_city_Greeley                   uint8
# seller_city_Greenacres                uint8
# seller_city_Greenfield                uint8
# seller_city_Greensboro                uint8
# seller_city_Greenwood                 uint8
# seller_city_Hagerstown                uint8
# seller_city_Harriman                  uint8
# seller_city_Hemet                     uint8
# seller_city_Henderson                 uint8
# seller_city_Hollywood                 uint8
# seller_city_Homestead                 uint8
# seller_city_Houston                   uint8
# seller_city_Huntersville              uint8
# seller_city_Huntington Beach          uint8
# seller_city_Hurst                     uint8
# seller_city_Irving                    uint8
# seller_city_Jackson                   uint8
# seller_city_Jacksonville              uint8
# seller_city_Jersey City               uint8
# seller_city_Johnson City              uint8
# seller_city_Joliet                    uint8
# seller_city_Joplin                    uint8
# seller_city_Kalamazoo                 uint8
# seller_city_Kansas City               uint8
# seller_city_Kearney                   uint8
# seller_city_Kenner                    uint8
# seller_city_Kennesaw                  uint8
# seller_city_Kenosha                   uint8
# seller_city_Killeen                   uint8
# seller_city_King George               uint8
# seller_city_La Place                  uint8
# seller_city_Lafayette                 uint8
# seller_city_Lake Charles              uint8
# seller_city_Lake City                 uint8
# seller_city_Lake In The Hills         uint8
# seller_city_Lakeland                  uint8
# seller_city_Langhorne                 uint8
# seller_city_Las Vegas                 uint8
# seller_city_Lemon Grove               uint8
# seller_city_Lenoir City               uint8
# seller_city_Lewisville                uint8
# seller_city_Lexington                 uint8
# seller_city_Libertyville              uint8
# seller_city_Lincolnton                uint8
# seller_city_Live Oak                  uint8
# seller_city_Livermore                 uint8
# seller_city_Lomira                    uint8
# seller_city_Longview                  uint8
# seller_city_Los Angeles               uint8
# seller_city_Louisville                uint8
# seller_city_Loveland                  uint8
# seller_city_Loves Park                uint8
# seller_city_Lufkin                    uint8
# seller_city_Maitland                  uint8
# seller_city_Manchester                uint8
# seller_city_Marlton                   uint8
# seller_city_Maryville                 uint8
# seller_city_McKinney                  uint8
# seller_city_Medina                    uint8
# seller_city_Medway                    uint8
# seller_city_Mesa                      uint8
# seller_city_Miami                     uint8
# seller_city_Miami Lakes               uint8
# seller_city_Middletown                uint8
# seller_city_Midwest City              uint8
# seller_city_Milpitas                  uint8
# seller_city_Milwaukee                 uint8
# seller_city_Minden                    uint8
# seller_city_Minneapolis               uint8
# seller_city_Mishawaka                 uint8
# seller_city_Mobile                    uint8
# seller_city_Monroe                    uint8
# seller_city_Montclair                 uint8
# seller_city_Montebello                uint8
# seller_city_Mooresville               uint8
# seller_city_Morristown                uint8
# seller_city_Mountain Home             uint8
# seller_city_Muncy                     uint8
# seller_city_Murrieta                  uint8
# seller_city_Muskogee                  uint8
# seller_city_Myrtle Beach              uint8
# seller_city_Naperville                uint8
# seller_city_Naples                    uint8
# seller_city_Nashville                 uint8
# seller_city_Natick                    uint8
# seller_city_National City             uint8
# seller_city_Negaunee                  uint8
# seller_city_New Bern                  uint8
# seller_city_New Braunfels             uint8
# seller_city_New Orleans               uint8
# seller_city_New Richmond              uint8
# seller_city_New York                  uint8
# seller_city_Newark                    uint8
# seller_city_Newnan                    uint8
# seller_city_Newport News              uint8
# seller_city_Norfolk                   uint8
# seller_city_Norman                    uint8
# seller_city_North Richland Hills      uint8
# seller_city_Norwood                   uint8
# seller_city_O Fallon                  uint8
# seller_city_O'Fallon                  uint8
# seller_city_Oak Ridge                 uint8
# seller_city_Oakland                   uint8
# seller_city_Okemos                    uint8
# seller_city_Oklahoma City             uint8
# seller_city_Olathe                    uint8
# seller_city_Omaha                     uint8
# seller_city_Ontario                   uint8
# seller_city_Orlando                   uint8
# seller_city_Owensboro                 uint8
# seller_city_Paducah                   uint8
# seller_city_Palm Bay                  uint8
# seller_city_Panama City               uint8
# seller_city_Paoli                     uint8
# seller_city_Parker                    uint8
# seller_city_Parkersburg               uint8
# seller_city_Pasco                     uint8
# seller_city_Pembroke Pines            uint8
# seller_city_Pensacola                 uint8
# seller_city_Peoria                    uint8
# seller_city_Pharr                     uint8
# seller_city_Philadelphia              uint8
# seller_city_Phoenix                   uint8
# seller_city_Pikeville                 uint8
# seller_city_Pittsburg                 uint8
# seller_city_Pittsburgh                uint8
# seller_city_Plainfield                uint8
# seller_city_Pleasant Hill             uint8
# seller_city_Plymouth                  uint8
# seller_city_Pompano Beach             uint8
# seller_city_Port Lavaca               uint8
# seller_city_Portage                   uint8
# seller_city_Portland                  uint8
# seller_city_Post Falls                uint8
# seller_city_Princeton                 uint8
# seller_city_Puyallup                  uint8
# seller_city_Rahway                    uint8
# seller_city_Raleigh                   uint8
# seller_city_Ransomville               uint8
# seller_city_Raytown                   uint8
# seller_city_Reading                   uint8
# seller_city_Reno                      uint8
# seller_city_Renton                    uint8
# seller_city_Richmond                  uint8
# seller_city_Riverside                 uint8
# seller_city_Rock Hill                 uint8
# seller_city_Rockville                 uint8
# seller_city_Rome                      uint8
# seller_city_Rosenberg                 uint8
# seller_city_Roseville                 uint8
# seller_city_Roswell                   uint8
# seller_city_Round Rock                uint8
# seller_city_Ruston                    uint8
# seller_city_Sacramento                uint8
# seller_city_Saint Charles             uint8
# seller_city_Saint Paul                uint8
# seller_city_Saint Peters              uint8
# seller_city_Saint Robert              uint8
# seller_city_Salinas                   uint8
# seller_city_San Antonio               uint8
# seller_city_San Bruno                 uint8
# seller_city_San Diego                 uint8
# seller_city_San Fernando              uint8
# seller_city_San Jose                  uint8
# seller_city_San Marcos                uint8
# seller_city_Sandy                     uint8
# seller_city_Sanford                   uint8
# seller_city_Santa Ana                 uint8
# seller_city_Santa Clara               uint8
# seller_city_Santa Fe                  uint8
# seller_city_Santa Maria               uint8
# seller_city_Santa Rosa                uint8
# seller_city_Sarasota                  uint8
# seller_city_Scottsdale                uint8
# seller_city_Seattle                   uint8
# seller_city_Signal Hill               uint8
# seller_city_Silver Spring             uint8
# seller_city_Sioux City                uint8
# seller_city_Somersworth               uint8
# seller_city_Soquel                    uint8
# seller_city_South Jordan              uint8
# seller_city_South San Francisco       uint8
# seller_city_Southaven                 uint8
# seller_city_Spokane                   uint8
# seller_city_Springfield               uint8
# seller_city_St Louis                  uint8
# seller_city_Starke                    uint8
# seller_city_Statesville               uint8
# seller_city_Sterling                  uint8
# seller_city_Stockton                  uint8
# seller_city_Stonewall                 uint8
# seller_city_Sugar Land                uint8
# seller_city_Surprise                  uint8
# seller_city_Tacoma                    uint8
# seller_city_Tallassee                 uint8
# seller_city_Tampa                     uint8
# seller_city_Taylorsville              uint8
# seller_city_Temecula                  uint8
# seller_city_Terrell                   uint8
# seller_city_Thousand Oaks             uint8
# seller_city_Tooele                    uint8
# seller_city_Torrington                uint8
# seller_city_Towson                    uint8
# seller_city_Troy                      uint8
# seller_city_Tucson                    uint8
# seller_city_Tulsa                     uint8
# seller_city_Tyler                     uint8
# seller_city_Uniontown                 uint8
# seller_city_Valparaiso                uint8
# seller_city_Vero Beach                uint8
# seller_city_Wall Township             uint8
# seller_city_Wapakoneta                uint8
# seller_city_Waukesha                  uint8
# seller_city_Weslaco                   uint8
# seller_city_West  Valley City         uint8
# seller_city_West Chester              uint8
# seller_city_West Chicago              uint8
# seller_city_West Covina               uint8
# seller_city_West Memphis              uint8
# seller_city_West Palm Beach           uint8
# seller_city_Westborough               uint8
# seller_city_Westminster               uint8
# seller_city_Whitesboro                uint8
# seller_city_Wichita                   uint8
# seller_city_Wickenburg                uint8
# seller_city_Williamsburg              uint8
# seller_city_Williamsville             uint8
# seller_city_Wilmington                uint8
# seller_city_Winchester                uint8
# seller_city_Windsor                   uint8
# seller_city_Winston Salem             uint8
# seller_city_Woodstock                 uint8
# seller_city_Wytheville                uint8
# seller_city_Yakima                    uint8
# seller_state_AL                       uint8
# seller_state_AR                       uint8
# seller_state_AZ                       uint8
# seller_state_CA                       uint8
# seller_state_CO                       uint8
# seller_state_CT                       uint8
# seller_state_FL                       uint8
# seller_state_GA                       uint8
# seller_state_IA                       uint8
# seller_state_ID                       uint8
# seller_state_IL                       uint8
# seller_state_IN                       uint8
# seller_state_KS                       uint8
# seller_state_KY                       uint8
# seller_state_LA                       uint8
# seller_state_MA                       uint8
# seller_state_MD                       uint8
# seller_state_ME                       uint8
# seller_state_MI                       uint8
# seller_state_MN                       uint8
# seller_state_MO                       uint8
# seller_state_MS                       uint8
# seller_state_NC                       uint8
# seller_state_NE                       uint8
# seller_state_NH                       uint8
# seller_state_NJ                       uint8
# seller_state_NM                       uint8
# seller_state_NV                       uint8
# seller_state_NY                       uint8
# seller_state_OH                       uint8
# seller_state_OK                       uint8
# seller_state_OR                       uint8
# seller_state_PA                       uint8
# seller_state_RI                       uint8
# seller_state_SC                       uint8
# seller_state_TN                       uint8
# seller_state_TX                       uint8
# seller_state_UT                       uint8
# seller_state_VA                       uint8
# seller_state_WA                       uint8
# seller_state_WI                       uint8
# seller_state_WV                       uint8
# seller_type_DEALER                    uint8
# listing_year_2019                     uint8
# listing_year_2020                     uint8
# listing_year_2021                     uint8
# listing_month_Apr                     uint8
# listing_month_Aug                     uint8
# listing_month_Dec                     uint8
# listing_month_Feb                     uint8
# listing_month_Jan                     uint8
# listing_month_Jul                     uint8
# listing_month_Jun                     uint8
# listing_month_Mar                     uint8
# listing_month_May                     uint8
# listing_month_Nov                     uint8
# listing_month_Oct                     uint8
# listing_month_Sep                     uint8
# dtype: object

# %%
# Export data 
df_train_final.to_csv(directory + '\\train.csv')
df_test_final.to_csv(directory + '\\test.csv')
